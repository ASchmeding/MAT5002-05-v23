# %% [markdown]
# # Utdrag fra en oppgave i programmering for trinn 10
#
# Notat inneholder bare programkode, ikke oppgavestilling (se ukentlige oppgaver for dette)

# %%
from pylab import *

def f(x):
    return x**2-2*x-1

x=linspace(-10,10,100)
y=f(x)

ylim(-3,6)
xlim(-4,4)
akser=gca()
akser.spines["bottom"].set_position('zero')
akser.spines["left"].set_position("zero")
akser.spines["top"].set_visible(False)
akser.spines["right"].set_visible(False)
  #Foreleseren har inkludert neste linjen, det treng i JUPYTER for å vise bildet
# %matplotlib inline  
plot(x,y)
grid()
show()

antall=int(input("Hvor mange nullpunkter skal vi finne?"))

for i in range(0,antall,1):
    print("\nVi finner nullpunkt nr.",i+1)
    under=float(input("Oppgi nedre grense:"))
    over =float(input("Oppgi øvre grense:"))
    
    for n in range (0,6,1):
        x_verdi=(under+over)/2
        if f(under)*f(x_verdi)<0:
            pver=x_verdi
        else: under=x_verdi
    
    print("Nullpunkt", i+1,":", round(x_verdi,4))
